# %%
# Edit this cell to print out your name.
print "My name is %s" % ("Brooke Snyder")
# Out:
# My name is Brooke Snyder

# %% [markdown]
# # Predicting the weather
#
# ***For all of the questions in this project, assume that 1 month = 30 days.***

# %% [markdown]
# ## Problem 1 (20 pts)
#
# Suppose there is a 20% chance it will rain on any given day in a month. What are the odds that that rains on one and only one day in a month.
#
# Work this problem out a*nalytically* (with pen and paper, using a formula) and write it up in your final document.
#
# Here you should solve the same problem *numerically* using a Monte Carlo approach, similar to how we approached the birthday problem in class.
#
# Make sure that both approaches give you a similar result.

# %%
# Your code here
#Bellis said use inclass_numpy assignment (monte carlo)


import numpy as np
from numpy import random 

def days_rain():
    
    rnums= random.random() #will import a random number 0-1 
    rain = False #will return if command in *if statement* below is not met 
    
     
    if rnums > 0 and rnums <= .2: #the prob it will rain, anything else, it wont rain 
        rain = True  #will return this if it is between the commands(will rain) *found on inclass numpy*
 
    return rain
################################
def chance_of_rain():
   
    totaldays=30 #number of days in the month, given above 
    list1= [] #created an empty list to allow the values from above to be added to the new function
    
    for j in range(0,totaldays): #goes through and goes up a number when listing from 0 to the total number of days 
        x= days_rain() #carries the above function in this cell, the 0 and 1 of whether it may rain    
        list1.append(x) #adding the random numbers generated from the above section to be found in the newlist
    
    
    if sum(list1) is 1: #adds the values of my list and then tells whether it rains for that day  
        return True #returns true if it rains that specific day 
    if sum(list1) != 1: ###is not (!=) Google 
        return False #returns if it doesnt rain which is a greater chance than if it does rain
     
print chance_of_rain()
################################### 
#Test it! *from inclass numpy*
ran_number_of_months = 990909 #a large number of months to get the percent as close as accuarte as possible to my analytical
#test 100 not big enough
#test 1000 not big enough
#test 10000 not big enough 

list2=[] 

for j in range(0,ran_number_of_months): 
    y = chance_of_rain()#bring the above function back in to test the values of true and false to see what percent it may rain
    list2.append(y) #adding the random numbers generated from the above section to be found in the newlist
        
totsum =sum(list2) 
print totsum

    
totaldays = 30

w = totsum/990909.0*100

print w
# Out:
# False
# 9215
# 0.929954213757

# %% [markdown]
# ## Problem 2 (20 pts)
#
# Suppose there is a 10% chance that it will rain on any given day in a month. What are the odds that it rains at least 8 days (in any order) that month?
#
# Work this problem out *numerically* using a Monte Carlo approach.

# %%
# Your code here
import numpy as np
from numpy import random 



def days_rain():
    
    rnums= random.random() #will import a random number 0-1 
    
    rain = False
    if rnums > 0 and rnums <= .1: #the prob it will rain, anything else, it wont rain 
        rain = True  #will return this if it is between the commands(will rain) *found on inclass numpy*
    
    return rain  
  
    
################################
def chance_of_rain():
   
    totaldays=30 #number of days in the month, given above 
    list1= [] #created an empty list to allow the values from above to be added to the new function
    
    for i in range(0,totaldays): #goes through and goes up a number when listing from 0 to the total number of days 
        x= days_rain() #carries the above function in this cell, the 0 and 1 of whether it may rain    
        list1.append(x) #adding the random numbers generated from the above section to be found in the newlist
    
    
    if sum(list1) >= 8: #atleast 8 days  
        return True #returns true if it rains that specific day 
    if sum(list1) < 8: #less than 8 days 
        return False 
        
        
print chance_of_rain()

############################

#Test it! *from inclass numpy*
ran_number_of_months = 1000000 #a large number of months to get the percent as close as accuarte as possible to my analytical
#test 100 not big enough
#test 1000 not big enough
#test 10000 not big enough 

list2=[] 

for i in range(0,ran_number_of_months): 
    y = chance_of_rain()#bring the above function back in to test the values of true and false to see what percent it may rain
    list2.append(y) #adding the random numbers generated from the above section to be found in the newlist
        
totsum =sum(list2) 
print totsum

   
percent_change= (totsum / 10000.0)



print percent_change
# Out:
# False
# 7756
# 0.7756

# %% [markdown]
# ## Problem 3
#
# ### 3a (20 pts)
#
# Suppose that if it rains one day, the odds of a certain amount of rainfall *on that day* are
#
# * 1 cm   20%
# * 2 cm   30%
# * 3 cm   30%
# * 4 cm   10%
# * 5 cm   10%
#
# However the odds of it raining are dependent on if it rained the day before.
#
# * If it is the first day of the month, there is a 10% chance of rain.
# * If it rained 1 day before, but not 2 days before, there is a 20% chance of rain.
# * If it rained both of the 2 days before, but not the 3rd day before, there is a 25% chance of rain.
# * If it rained for the 3 days (or more) before, there is a 5% chance of rain.
# * Otherwise, there is a 10% chance of rain
#
# What are the odds that there are at least 10 cm of rain in a given month?
#
# Work this problem out using a Monte Carlo approach.

# %%
# Your code here

####LIKE THE DICE PROBLEM 



from numpy import random

def rain():
    
    rnd_num = random.random() # This generated a random number between 0 - 1.
    
    if rnd_num >= 0 and rnd_num .2/1:
        rain_fall = 1
        
    elif rnd_num >= .2/1 and rnd_num < .3/1:
        rain_fall = 2
        
    elif rnd_num >= .2/1 and rnd_num < .3/1:
        rain_fall = 3
        
    elif rnd_num >= .3/1 and rnd_num < .1/1:
        rain_fall = 4
        
           
    elif rnd_num >= .1/1 and rnd_num < .1/1:
        rain_fall = 5    
        
        
        
    return rain_fall  





#attempted but not sure how to get any further
# Out:
#   File "<ipython-input-73-5043497fb080>", line 8
#     if rnd_num >= 0 and rnd_num .2/1:
#                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 3b (10 pts)
#
# Make a histogram of the distribtion of expected rainfall values. You can get this from your Monte Carlo trials.
#
# Make sure you label everything clearly.

# %%
# Your code here?


import matplotlib.pylab as plt
# %matplotlib notebook

rnums= random.random(100) #100 random numbers between 0-1

list1=[] #create empty list to place the the random numbers into to genterate 
list1.append(rnums) 

plt.figure()
plt.title("Rainfall")
plt.hist(list1,bins=10,range=(0,1),color="b",histtype="stepfilled")
plt.ylabel("Amount of days per amount")
plt.xlabel("Amount of Percipitation")
plt.ylim(0,20)
plt.xlim(0,1)







#bellis said keep track of data to make the graph with
# Out:
# <img src="data:image/png;base64,...">
# (0, 1)

# %% [markdown]
# ### 3c (10 pts)
#
# What is the average amount of rain to fall in any given month?

# %%
# Your code here?

# %% [markdown]
# ### 3d (20)
#
# Once you find the average value, someone might ask you for the uncertainty (some people also refer to uncertainty as the "*error*") on your prediction. That can be tricky to calculate, so often what is given is just a *range* of possible values. "We estimate the rainfall to be between X cm and Y cm." The question is, how to decide what that range is.
#
# The way this is often done is to find the middle 95% of the trial values (from your Monte Carlo run) and then use the low-edge and the high-edge of that range. If you're concerned about the middle 95%, then 2.5% of the values are below them and 2.5% of all the values are above them. The rainfall values at those edges are what you use for the ranges to quote.
#
# This is what people mean when they say, "I'm 95% confident that the rainfall will be between X and Y", and when you write it up for the LaTeX document, you should also quote it this way.
#
# *Hint!* This part becomes much easier if you sort all the values using any of the numpy/Python sort functions you can read about online. When you sort them, you should be able to find what rainfall is at the edge for the lower 2.5% and the higher 2.5%.

# %%
# Your code here


#bellis said the middle 95, not the forst 2.5 or last 2.5
#bellis said make histogram and then look at this
